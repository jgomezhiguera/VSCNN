# %%
from google.colab import drive
import tensorflow as tf
import keras
import numpy as np
from os import listdir
from os.path import isfile, join
import cv2
import pandas as pd
import re
import matplotlib.pyplot as plt
import random
import os

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
#import patoolib

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from fastai.vision import *
from fastai.metrics import error_rate, accuracy
import warnings
warnings.filterwarnings('ignore')

# %%
path = Path('/content/drive/My Drive/Us')

# %%
data = ImageDataBunch.from_folder(path, train='train', valid='val', ds_tfms=get_transforms(do_flip=True, flip_vert=True, max_rotate=20.0, max_zoom=1.5), size=128, bs=32, classes=['0', '1'])

# %%
print(len(data.train_ds), len(data.valid_ds))
# Out:
# 45646 1194

# %%
learn = cnn_learner(data, models.resnet18, metrics = [accuracy])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# ...

# %%
learn.fit_one_cycle(50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.882039</td>
#       <td>0.738291</td>
#       <td>0.526801</td>
#       <td>40:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.715765</td>
#       <td>0.700444</td>
#       <td>0.509213</td>
#       <td>09:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.698037</td>
#       <td>0.695614</td>
#       <td>0.524288</td>
#       <td>10:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.709130</td>
#       <td>0.695255</td>
#       <td>0.540201</td>
#       <td>10:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.712837</td>
#       <td>0.698051</td>
#       <td>0.516750</td>
#       <td>10:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...
